# %% [markdown]
# ### importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 1. Download the dataset
# ### 2. Load the dataset.

# %%
df=pd.read_csv('/content/House Price India.csv')
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %% [markdown]
# ### 3. Perform the Below Visualizations

# %% [markdown]
# ###Univariate Analysis

# %% [markdown]
# number of views

# %%
df['number of views'].value_counts()
# Out:
# 0    13198
# 2      636
# 3      351
# 1      219
# 4      216
# Name: number of views, dtype: int64

# %%
sns.distplot(df['number of views'])
# Out:
# <ipython-input-4-edd14fddb5fd>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['number of views'])
# <Axes: xlabel='number of views', ylabel='Density'>

# %%
sns.displot(df['number of views'])

# %%
plt.pie(df['number of views'].value_counts(),[0,0,0.1,0.2,0.3],labels=[0,2,3,1,4],autopct='%1.1f%%',shadow=True)
plt.title('number of views')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(x=df['number of views'].value_counts().index,y=df['number of views'].value_counts())
# Out:
# <Axes: ylabel='number of views'>

# %% [markdown]
# number of floors

# %%
df['number of floors'].value_counts()
# Out:
# 1.0    7103
# 2.0    5666
# 1.5    1311
# 3.0     418
# 2.5     118
# 3.5       4
# Name: number of floors, dtype: int64

# %%
sns.distplot(df['number of floors'])
# Out:
# <ipython-input-9-4bce24ad8e73>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['number of floors'])
# <Axes: xlabel='number of floors', ylabel='Density'>

# %%
plt.pie(df['number of floors'].value_counts(),[0,0,0,0.1,0.2,0.4],labels=[1.0,2.0,1.5,3.0,2.5,3.5],autopct='%1.1f%%',shadow=True,colors=['red','yellow','blue','purple','orange','skyblue'])
plt.title('number of floors')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(x=df['number of floors'].value_counts().index,y=df['number of floors'].value_counts())
# Out:
# <Axes: ylabel='number of floors'>

# %% [markdown]
# Number of schools nearby

# %%
df['Number of schools nearby'].value_counts()
# Out:
# 3    4973
# 2    4853
# 1    4794
# Name: Number of schools nearby, dtype: int64

# %%
sns.distplot(df['Number of schools nearby'])
# Out:
# <ipython-input-13-fa31314a9a8c>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Number of schools nearby'])
# <Axes: xlabel='Number of schools nearby', ylabel='Density'>

# %%
plt.pie(df['Number of schools nearby'].value_counts(),[0,0,0.1],labels=[3,2,1],autopct='%1.1f%%',shadow=True,colors=['red','yellow','blue'])
plt.title('Number of schools nearby')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(x=df['Number of schools nearby'].value_counts().index,y=df['Number of schools nearby'].value_counts())
# Out:
# <Axes: ylabel='Number of schools nearby'>

# %% [markdown]
# condition of the house

# %%
df['condition of the house'].value_counts()
# Out:
# 3    9350
# 4    3874
# 5    1278
# 2     100
# 1      18
# Name: condition of the house, dtype: int64

# %%
sns.distplot(df['condition of the house'])
# Out:
# <ipython-input-17-e62300829dc7>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['condition of the house'])
# <Axes: xlabel='condition of the house', ylabel='Density'>

# %%
plt.pie(df['condition of the house'].value_counts(),[0,0,0.1,0,0.3],labels=[3,4,5,2,1],autopct='%1.1f%%',shadow=True,colors=['red','yellow','blue','purple','orange'])
plt.title('condition of the house')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(x=df['condition of the house'].value_counts().index,y=df['condition of the house'].value_counts())
# Out:
# <Axes: ylabel='condition of the house'>

# %% [markdown]
# ### Bivariate analysis

# %% [markdown]
#  number of bedrooms vs Price

# %%
sns.lineplot(x=df['number of bedrooms'],y=df['Price'])
# Out:
# <Axes: xlabel='number of bedrooms', ylabel='Price'>

# %%
sns.scatterplot(x=df['number of bedrooms'],y=df['Price'])
# Out:
# <Axes: xlabel='number of bedrooms', ylabel='Price'>

# %%
sns.jointplot(x='number of bedrooms' ,y='Price',data=df)

# %% [markdown]
# condition of the house vs Price

# %%
sns.lineplot(x=df['condition of the house'],y=df['Price'])
# Out:
# <Axes: xlabel='condition of the house', ylabel='Price'>

# %%
sns.scatterplot(x=df['condition of the house'],y=df['Price'])
# Out:
# <Axes: xlabel='condition of the house', ylabel='Price'>

# %%
sns.jointplot(x='condition of the house' ,y='Price',data=df)

# %% [markdown]
# ### Multivariate Analysis

# %%
sns.pairplot(df)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
plt.subplots(figsize= (23, 23))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### 4. Perform descriptive statistics on the dataset.

# %%
df.describe()
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...

# %% [markdown]
# ### 5. Handle the Missing values.

# %%
df.isnull().any()
# Out:
# id                                       False
# Date                                     False
# number of bedrooms                       False
# number of bathrooms                      False
# living area                              False
# lot area                                 False
# number of floors                         False
# waterfront present                       False
# number of views                          False
# condition of the house                   False
# grade of the house                       False
# Area of the house(excluding basement)    False
# Area of the basement                     False
# Built Year                               False
# Renovation Year                          False
# Postal Code                              False
# Lattitude                                False
# Longitude                                False
# living_area_renov                        False
# lot_area_renov                           False
# ...

# %%
df.isnull().sum()
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# ...

# %% [markdown]
# Conclusion : In the given dataset there are no null values.
